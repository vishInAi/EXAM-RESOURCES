# %% [markdown]
# ---
#
# **Set 1 – Basic Concepts, Networking & Topologies**
# • **Q2. Benefits of computer network are**
#  – Options: File-Sharing; Hardware-Sharing; Network Gaming
#
# • **Q4. Effectiveness of data communication depends upon**
#  – Options: Delivery; Accuracy; Timeliness
#
# • **Q6. The main uses of computer networks are in:**
#  – Options: Business; Home; Mobile
#
# • **Q10. Select applications of computer networks**
#  – Options: Information and resource sharing; Retrieving Remote Information; E-Commerce
#
# ---
#
# **Set 2 – Signals, Data Transmission & Impairments**
# • **Q7. Causes of Impairment**
#  – Options: Attenuation; Distortion; Noise
#
# • **Q15. Select essential network performance metrics**
#  – Options: Bandwidth usage; Throughput; Latency
#
# ---
#
# **Set 3 – Digital Coding, Line Codes & Error Control**
# • **Q7. Techniques used for digital-to-analog conversion are**
#  – Options: ASK; PSK; FSK
#
# • **Q9. The advantages of Frequency Shift Keying**
#  – Options: The transmitter and receiver implementations are simple; Provides high signal to noise ratio; Lower chances of an error
#
# ---
#
# **Set 4 – Block Coding, ARQ & Data Link Layer Services**
# • **Q9. Services provided by data link protocols are**
#  – Options: Framing; Flow Control; Error Detection and/or Correction
#
# • **Q11. Select data link protocols**
#  – Options: Error control; Flow control; Framing
#
# ---
#
# **Set 5 – HDLC, ALOHA, CSMA Protocols**
# • **Q5. Multiple access protocols include**
#  – Options: Random-access protocols; Control-access protocols; Channelization protocols
#
# • **Q12. Types of CSMA include**
#  – Options: 1-Persistent CSMA; P-Persistent CSMA; Non-Persistent CSMA
#
# ---
#
# **Set 6 – IP Addressing, Subnetting, NAT, ICMP & MAC**
# • **Q14. Types of NAT include**
#  – Options: Static NAT; Dynamic NAT; NAT/PAT
#
# ---
#
# **Set 7 – Routing, Graphs & Dijkstra’s Algorithm**
# • **Q10. Characteristics of MANET include**
#  – Options: Dynamic Topologies; Bandwidth constrained, variable capacity links; Autonomous Behavior
#
# • **Q12. Types of graphs include**
#  – Options: Undirected graph; Directed; Weighted graph
#
# ---
#
# **Set 8 – Transport Layer Services & Protocols**
# • **Q1. Select services of transport layer**
#  – Options: Flow control; Addressing; Reliable delivery
#
# ---
#
# **Set 9 – Congestion Control & QoS**
# • **Q9. Select flow characteristics of congestion control**
#  – Options: Reliability; Delay; Jitter
#
# ---
#
# **Set 10 – Telnet, Email, DNS, and Related Services**
# • **Q5. Modes of operation in Telnet**
#  – Options: Default mode; Character mode; Line mode
#
# • **Q7. Services of a user agent include**
#  – Options: Composing messages; Reading messages; Forwarding messages
#
# • **Q9. GUI-based user agents include**
#  – Options: Eudora; Outlook; Netscape
#
# • **Q13. Sections of domain name space include**
#  – Options: generic domains; country domains; inverse domain
#
# ---
#
# **Set 11 – IP Security, VPN, Encryption & Digital Certificates**
# • **Q5. Use of IP Security includes**
#  – Options: To encrypt application layer data; To provide security for routers; To provide authentication without encryption
#
# ---
#
# **Set 12 – Network Security Issues, Cryptography & Firewalls**
# • **Q1. Various network security issues include**
#  – Options: Physical security holes; Software security holes; Inconsistent usage holes
#
# • **Q3. Firewall techniques include**
#  – Options: Packet filters; Application gateways; Proxy server
#
# • **Q8. Security services include**
#  – Options: Data confidentiality; Access control; Non-repudiation
#
# • **Q11. Security approaches include**
#  – Options: Prevention; Protection; Resilience
#
# • **Q14. Core principles of modern-day cryptography include**
#  – Options: Data Confidentiality; Data Integrity; Authentication
#
# • **Q16. Types of firewall include**
#  – Options: Packet-filtering Firewalls; Circuit-level Gateways; Software Firewalls
#
# • **Q17. (Repeat) Type of firewall**
#  – Options: Packet-filtering Firewalls; Circuit-level Gateways; Software Firewalls
#
# ---
