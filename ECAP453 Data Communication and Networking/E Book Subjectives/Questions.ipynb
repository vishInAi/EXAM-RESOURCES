# %% [markdown]
# 1. Explain five effective characteristics of data communication.
# 2. Write down applications of computer networks.
# 3. How are computer networks classified? Mention some important reasons for their classification.
# 4. Diagrammatically explain bus topology and ring topology.
# 5. Explain the difference between Star, Bus, and Mesh topology.
# 6. Write down the difference between LAN, MAN, and WAN.
# 7. Difference between bit rate and baud rate.
# 8. Explain different types of modes of communication.
# 9. Explain the difference between full duplex, half duplex, and simplex, along with examples.
# 10. Write down the standards of organization.
# 11. What do you understand by signals? Explain types of signals also.
# 12. There are always three causes of impairment. Explain them in detail.
# 13. Difference between periodic and non-periodic signals.
# 14. Write a note on:
#    a. Bit rate
#    b. Baud rate
#    c. Bit length
#    d. Bit interval
# 15. What do you understand by De facto and De jure?
# 16. What do you understand by protocol? Explain protocol architecture.
# 17. What are the most significant design considerations for computer-to-computer communication?
# 18. In the ISO-OSI paradigm, what are the main roles of the network layer? What distinguishes the network layer's packet delivery role from that of the data link layer?
# 19. In the OSI reference model, what is the objective of layer isolation?
# 20. Why is the OSI Reference Model so extensively used? What good did it do to establish itself as a data transmission standard?
# 21. Compare and contrast the OSI reference model with the TCP/IP model.
# 22. What is the data link protocol?
# 23. What advantages does the Selective Repeat sliding window protocol offer over the Go-Back-N protocol?
# 24. What is the purpose of flow control?
# 25. Describe how the finite state machine model carries out protocol verification.
# 26. What are the different data link protocols available? Why has PPP become popular?
# 27. Explain error detection techniques.
# 28. Explain Hamming code with an example.
# 29. How does the data link layer accomplish the transmission of data from the source network layer to the destination network layer?
# 30. Compare and contrast a random-access protocol with a channelizing protocol.
# 31. Do we need a multiple access protocol when we use the local loop of the telephone company to access the Internet? Why?
# 32. Define channelization and list three protocols in this category.
# 33. How does PPP establish a link for authenticated transfer of files?
# 34. Compare and contrast CSMA/CD and token passing access methods.
# 35. Is Slotted Aloha always better than Aloha? Explain your answer with justification.
# 36. List three categories of multiple access protocols.
# 37. How can a collision be avoided in a CSMA/CD network?
# 38. How does PPP transmit datagrams over serial point-to-point links?
# 39. Describe briefly how the hierarchical algorithm works.
# 40. What is the main purpose of using a router in a network?
# 41. Differentiate between:
#    a. Connectionless and connection-oriented service
#    b. Interior and Exterior Routing
#    c. Link state and distance vector routing
# 42. Difference between proactive and reactive routing protocols.
# 43. What is the purpose of BGP?
# 44. Why do OSPF messages propagate faster than RIP messages?
# 45. When the facilities delivered at both layers are almost identical, how is the transport layer different from the data link layer?
# 46. Why is the transport layer required when both the network and transport layers provide connectionless and connection-oriented services?
# 47. What are the different quality of service parameters at the transport layer?
# 48. Why is UDP used when it provides unreliable connectionless service to the transport layer?
# 49. What is the purpose of flow control?
# 50. Describe TCP and its major advantages over UDP.
# 51. What is FTTP?
# 52. Write advantages and disadvantages of HTTP.
# 53. Write down components and features of WWW.
# 54. Write down the most commonly used Telnet commands.
# 55. Explain E-mail. Write down components of E-mail.
# 56. What is the domain name system?
# 57. Write down the hierarchy of DNS.
# 58. Write down the difference between POP3 and IMAP.
# 59. Difference between Free VPN and paid VPN.
# 60. What is IP Security?
# 61. What is E-mail security?
# 62. Explain components of IP Security.
# 63. Write down steps for establishing a digital signature.
# 64. Write down the difference between a digital signature and a digital certificate.
# 65. Explain types of signatures.
# 66. What are the benefits of this sort of network in which IP addresses are routed to the server?
# 67. Explain the working of IP Security.
# 68. Difference between private key and public key.
# 69. What are different criteria to keep information private when it is sent over a public network?
# 70. How does encryption affect the performance of a network?
# 71. How can undesirable persons be prevented from accessing certain information bases on the Internet?
# 72. How do we keep our own and other people’s computers safe from hackers? Explain with a hypothetical situation.
# 73. What is a Cipher? Why are ciphers used for large messages?
# 74. Describe briefly two kinds of security attacks that can be directed against an Internet-connected computer system.
# 75. What is the difference between secret key and public key encryption?
# 76. What is cryptography? What are the benefits of using this technique?
# 77. What do you mean by substitution and transposition ciphers? Differentiate between the two.
