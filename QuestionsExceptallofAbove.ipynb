# %% [markdown]
# ---
#
# **Set 1 – Basic Concepts, Networking & Topologies**
#
# 1. **Resources related to hardware is**
#  **Answer:** Printer
#
# 2. **Local Sharing means**
#  **Answer:** Means two users are directly communicating with one another.
#
# 3. **There are ______ components of data communication**
#  **Answer:** 5
#
# 4. **In a client server model**
#  **Answer:** Client sends a request
#
# 5. **P2P communication stands for**
#  **Answer:** Peer to peer communication
#
# 6. **______________ is when someone gains access using someone else's account**
#  **Answer:** Unauthorized access
#
# 7. **___________ is normally located inside the same building or structure**
#  **Answer:** LAN
#
# 8. **Select true statement for Peer-to-Peer network**
#  **Answer:** Do not have a central control system
#
# 9. **MAN is known as**
#  **Answer:** Metro area network
#
# 10. **WAN stands for**
#  **Answer:** Wide Area Network
#
# 11. **A __________ is the interconnection of devices within a range of 10 meters**
#  **Answer:** PAN
#
# 12. **In a __________, each node is connected to a single cable**
#  **Answer:** Bus topology
#
# 13. **In __________ topology, data is sent using a token**
#  **Answer:** Ring topology
#
# 14. **Tree Topology integrates the characteristics of ____ and _____**
#  **Answer:** Bus and Star
#
# 15. **Hybrid topology is**
#  **Answer:** A mixture of two different things
#
# 16. **Dependency on central cable in bus topology has its disadvantages**
#  **Answer:** True
#
# ---
#
# **Set 2 – Signals, Data Transmission & Impairments**
#
# 1. **The term analog data refers to information that is**
#  **Answer:** Continuous
#
# 2. **What type of signals consist of a limited number of defined values?**
#  **Answer:** Digital Signal
#
# 3. **Which signal completes a pattern and repeats that pattern?**
#  **Answer:** Periodic Signal
#
# 4. **The ___ rate is the number of bits sent in 1 second**
#  **Answer:** Bit rate
#
# 5. **The ______ length is the distance one bit occupies on the transmission medium**
#  **Answer:** Bit
#
# 6. **Imperfections in transmission media cause**
#  **Answer:** Signal impairment
#
# 7. **Attenuation means**
#  **Answer:** Weaker the signal
#
# 8. **Distortion means**
#  **Answer:** Signal changes its form or shape
#
# 9. **The effect of one wire on another is called**
#  **Answer:** Crosstalk
#
# 10. **_____________ refers to transferring data between two devices**
#  **Answer:** Data Communication
#
# 11. **There are ___ modes of transmission**
#  **Answer:** 3
#
# 12. **In __________ transmission mode, data can be sent only in one direction**
#  **Answer:** Simplex
#
# 13. **In __________ transmission mode, data can be sent in both directions (but not simultaneously)**
#  **Answer:** Half-duplex
#
# ---
#
# **Set 3 – Digital Coding, Line Codes & Error Control**
#
# 1. **A __________ digital signal includes timing information**
#  **Answer:** Self-synchronizing
#
# 2. **The ________ rate defines the number of data elements sent in 1 second**
#  **Answer:** Bit rate
#
# 3. **The ________ rate defines the number of signal elements sent in 1 second**
#  **Answer:** Baud rate
#
# 4. **The signal rate is sometimes called the _______**
#  **Answer:** Baud rate
#
# 5. **____________ technique is a combination of RZ and NRZ-I**
#  **Answer:** Differential Manchester
#
# 6. **A digital signal represents data as a sequence of**
#  **Answer:** Discrete values
#
# 7. **A disadvantage of Amplitude Shift Keying is that it is**
#  **Answer:** Susceptible to noise interference
#
# 8. **_______ allows the signal to carry twice as much information as ordinary PSK**
#  **Answer:** QPSK
#
# 9. **Periodic analog signals can be classified as**
#  **Answer:** Both simple and composite
#
# 10. **The voltage of a battery, being constant, is considered a**
#  **Answer:** DC level
#
# 11. **If a signal does not change at all, its frequency is**
#  **Answer:** 0
#
# 12. **The range of frequencies in a composite signal is its**
#  **Answer:** Bandwidth
#
# ---
#
# **Set 4 – Block Coding, ARQ & Data Link Layer Services**
#
# 1. **In block coding, we divide our message into blocks called**
#  **Answer:** Datawords
#
# 2. **When one bit is changed during transmission, that error is called a**
#  **Answer:** Single bit error
#
# 3. **A frame received with more than one bit corrupted is called a**
#  **Answer:** Multibit error
#
# 4. **A frame with more than one consecutive bit error is called a**
#  **Answer:** Burst error
#
# 5. **Extra bits sent for error detection/correction are called**
#  **Answer:** Redundant
#
# 6. **The Hamming distance d(000, 011) is**
#  **Answer:** 2
#
# 7. **The minimum Hamming distance in the coding scheme is**
#  **Answer:** 2
#
# 8. **The data link layer functions include both data link control and media access control**
#  **Answer:** Both
#
# 9. **The data link layer packs bits into**
#  **Answer:** Frames
#
# 10. **Data link protocols operate over**
#  **Answer:** Noisy channels
#
# 11. **The protocol suited for noisy channels is**
#  **Answer:** Stop and wait ARQ
#
# 12. **Protocols that allow multiple frames to be sent at a time are**
#  **Answer:** Sliding window protocol
#
# 13. **In Go-Back-N ARQ, N is the sender’s**
#  **Answer:** Window size
#
# 14. **If no acknowledgment for a frame is received, the protocol used is**
#  **Answer:** Go-Back-N ARQ
#
# 15. **Both Go-Back-N and Selective Repeat ARQ use a**
#  **Answer:** Sliding window
#
# 16. **In Selective Repeat ARQ with a 5‑bit sequence number, the maximum window size is**
#  **Answer:** 16
#
# ---
#
# **Set 5 – HDLC, ALOHA, CSMA Protocols**
#
# 1. **Bit Oriented protocol is**
#  **Answer:** HDLC
#
# 2. **HDLC operations include**
#  **Answer:** Framing
#
# 3. **HDLC stands for**
#  **Answer:** High-level Data Link Control
#
# 4. **Aloha is a __________ access protocol**
#  **Answer:** Random
#
# 5. **The correct versions of ALOHA are**
#  **Answer:** Pure and Slotted Aloha
#
# 6. **Pure Aloha allows stations to transmit data at any time**
#  **Answer:** Pure Aloha
#
# 7. **Aloha that divides the channel time into slots is**
#  **Answer:** Slotted Aloha
#
# 8. **CSMA stands for**
#  **Answer:** Carrier Sense Multiple Access
#
# 9. **The principal of CSMA is to**
#  **Answer:** Sense before transmit
#
# 10. **In methods where no station is superior, the approach is**
#  **Answer:** Random access
#
# 11. **The extension of CSMA to detect collisions is**
#  **Answer:** CSMA/CD
#
# 12. **For wireless networks, the collision-avoidance method is**
#  **Answer:** CSMA/CA
#
# 13. **When a station must be authorized before sending, the method is**
#  **Answer:** Controlled access
#
# ---
#
# **Set 6 – IP Addressing, Subnetting, NAT, ICMP & MAC**
#
# 1. **IPv4 addressing originally used the concept of**
#  **Answer:** Classes
#
# 2. **There are ____ prevalent notations for an IPv4 address**
#  **Answer:** Three
#
# 3. **IPv4 addresses are usually written in**
#  **Answer:** Decimal form (with dots)
#
# 4. **Select the class of the given binary address (based on the first octet)**
#  **Answer:** Class A
#
# 5. **The range of Class B is**
#  **Answer:** 128–191
#
# 6. **IP stands for**
#  **Answer:** Internet Protocol
#
# 7. **IPv4 is expressed in**
#  **Answer:** N.N.N.N format
#
# 8. **Each octet in an IP address ranges from**
#  **Answer:** 0–255
#
# 9. **IPv4 is a ______‑bit address**
#  **Answer:** 32
#
# 10. **IPv6 is a __________‑bit address**
#  **Answer:** 128
#
# 11. **The broadcast address for a Class B network (default mask) is**
#  **Answer:** 172.16.255.255
#
# 12. **For 12 subnets in a Class C network, the subnet mask used is**
#  **Answer:** 255.255.255.240
#
# 13. **Full form of NAT is**
#  **Answer:** Network Address Translation
#
# 14. **ICMP stands for**
#  **Answer:** Internet Control Message Protocol
#
# 15. **ICMP is used for**
#  **Answer:** Error reporting
#
# 16. **If an IP packet is discarded, the feedback packet is an**
#  **Answer:** ICMP packet
#
# 17. **An IP address is a**
#  **Answer:** Unique address
#
# 18. **A MAC Address is a**
#  **Answer:** Hardware identification number
#
# 19. **The binary number 1110000110001000011111000011001 converts to**
#  **Answer:** 112.196.62.25
#
# 20. **The decimal number 30610 converts to binary as**
#  **Answer:** 100110010
#
# 21. **Class A uses how many bytes for network and host IDs?**
#  **Answer:** 1 byte for Network ID and 3 bytes for Host ID
#
# 22. **Which class is never divided into host and network parts?**
#  **Answer:** Class D
#
# 23. **The number of networks and hosts in Class B are**
#  **Answer:** 16384 networks and 65534 hosts
#
# 24. **The range of Class C addresses is**
#  **Answer:** 192–223
#
# 25. **Class D is used for**
#  **Answer:** Multicast
#
# ---
#
# **Set 7 – Routing, Graphs & Dijkstra’s Algorithm**
#
# 1. **_______ means transmission from a single sender to a single receiver**
#  **Answer:** Unicast
#
# 2. **Path vector routing is exemplified by**
#  **Answer:** BGP
#
# 3. **For unicast routing, one protocol used is**
#  **Answer:** Distance vector routing
#
# 4. **The least-cost route is the route with**
#  **Answer:** Minimum distance
#
# 5. **A node sends its table every 30 seconds in a**
#  **Answer:** Periodic update
#
# 6. **One-to-one communication happens in**
#  **Answer:** Unicast
#
# 7. **A type of broadcast routing is**
#  **Answer:** Limited Broadcasting
#
# 8. **Routing where packets are sent to all nodes is**
#  **Answer:** Broadcast
#
# 9. **MANET stands for**
#  **Answer:** Mobile Adhoc Network
#
# 10. **Graphs represent connections between elements called**
#  **Answer:** Nodes
#
# 11. **Dijkstra’s Algorithm solves the**
#  **Answer:** Single source shortest path problem
#
# 12. **The common data structure used for Dijkstra’s Algorithm is a**
#  **Answer:** Min priority queue
#
# 13. **Dijkstra’s Algorithm cannot be applied to graphs with**
#  **Answer:** Negative weight functions
#
# ---
#
# **Set 8 – Transport Layer Services & Protocols**
#
# 1. **Transport ensures the __ delivery**
#  **Answer:** End-to-end
#
# 2. **A key aspect of reliable delivery is**
#  **Answer:** Error control
#
# 3. **Connection-oriented and reliable protocols include**
#  **Answer:** Both TCP and SCTP
#
# 4. **The connectionless protocol is**
#  **Answer:** UDP
#
# 5. **TCP and UDP are called**
#  **Answer:** Transport protocols
#
# 6. **A security-based connection is provided by the**
#  **Answer:** Session layer
#
# 7. **For sending a small message without high reliability, one can use**
#  **Answer:** UDP
#
# 8. **FTP typically uses port**
#  **Answer:** 21
#
# 9. **SNMP uses port numbers**
#  **Answer:** 161 and 162
#
# 10. **The UDP header is**
#  **Answer:** 8 bytes
#
# 11. **The UDP length is calculated as**
#  **Answer:** IP length minus UDP header’s length
#
# 12. **TFTP stands for**
#  **Answer:** Trivial File Transfer Protocol
#
# 13. **UDP is used for route updating protocols such as**
#  **Answer:** Routing Information Protocol (RIP)
#
# ---
#
# **Set 9 – Congestion Control & QoS**
#
# 1. **The main focus of congestion control and QoS is**
#  **Answer:** Data traffic
#
# 2. **Congestion occurs when the network load is**
#  **Answer:** Greater than the capacity
#
# 3. **A congestion control mechanism is**
#  **Answer:** Open loop congestion control
#
# 4. **An open loop control mechanism example is**
#  **Answer:** Choke packet
#
# 5. **When there is no communication between congested nodes and the source, signaling is**
#  **Answer:** Implicit signaling
#
# 6. **Explicit signaling can occur in**
#  **Answer:** Forward and backward directions
#
# 7. **Retransmission of packets should not occur when the packet is**
#  **Answer:** Error-free
#
# 8. **In open-loop control, policies are applied to**
#  **Answer:** Prevent before congestion occurs
#
# 9. **Lack of reliability means**
#  **Answer:** Losing a packet or acknowledgment
#
# 10. **Variation in packet delay (jitter) is called**
#  **Answer:** Jitter
#
# 11. **A traffic shaping technique example is**
#  **Answer:** Both leaky bucket and token bucket
#
# 12. **The mechanism to control the amount and rate of traffic is**
#  **Answer:** Traffic shaping
#
# 13. **QoS can be improved if resources are**
#  **Answer:** Reserved beforehand
#
# ---
#
# **Set 10 – Telnet, Email, DNS, and Related Services**
#
# 1. **Telnet developed in**
#  **Answer:** 1969
#
# 2. **TELNET was proposed by**
#  **Answer:** DOD (Department of Defense)
#
# 3. **When accessing a remote application, the log-in is called**
#  **Answer:** Remote
#
# 4. **The TELNET client converts characters to the universal set called**
#  **Answer:** Network Virtual Terminal (NVT)
#
# 5. **When sender and receiver of an e-mail are on the same system, only**
#  **Answer:** One user agent is needed
#
# 6. **Command-driven user agents include**
#  **Answer:** Mail, pine, Elm
#
# 7. **MIME stands for**
#  **Answer:** Multipurpose Internet Mail Extensions
#
# 8. **DNS stands for**
#  **Answer:** Domain Name System
#
# 9. **A server that loads all information from a disk file is the**
#  **Answer:** Primary server
#
# 10. **WWW stands for**
#  **Answer:** World Wide Web
#
# 11. **HTML stands for**
#  **Answer:** Hypertext Markup Language
#
# ---
#
# **Set 11 – IP Security, VPN, Encryption & Digital Certificates**
#
# 1. **IETF stands for**
#  **Answer:** Internet Engineering Task Force
#
# 2. **Components of IP security include**
#  **Answer:** Both AH and IKE
#
# 3. **Sending unsolicited bulk emails is known as**
#  **Answer:** Spamming
#
# 4. **VPN stands for**
#  **Answer:** Virtual Private Network (VPN)
#
# 5. **A Virtual Private Network is a type of**
#  **Answer:** Private network
#
# 6. **The backbone for VPNs is the**
#  **Answer:** Internet
#
# 7. **Protocols used in VPNs are**
#  **Answer:** Tunnelling protocols
#
# 8. **An isolated tunnel across a public network is provided by the**
#  **Answer:** Virtual Private Network
#
# 9. **An encryption ___ is a random string used for scrambling data**
#  **Answer:** Key
#
# 10. **PKI stands for**
#  **Answer:** Public Key Infrastructure
#
# 11. **A digital certificate establishes a relationship between a ____ and the ______ key**
#  **Answer:** User and public key
#
# 12. **The standard for digital certificates is defined by**
#  **Answer:** X.509
#
# ---
#
# **Set 12 – Network Security Issues, Cryptography & Firewalls**
#
# 1. **Protection methods include**
#  **Answer:** Both authorization and authentication
#
# 2. **A key layer of protection is**
#  **Answer:** Encryption
#
# 3. **CIA stands for**
#  **Answer:** Confidentiality Integrity Availability
#
# 4. **Integrity measures protect information from**
#  **Answer:** Unauthorized alteration
#
# 5. **Repudiation means**
#  **Answer:** Denial of truth
#
# 6. **Unsolicited commercial email is known as**
#  **Answer:** Spam
#
# 7. **Prevention generally comes**
#  **Answer:** Before protection
#
# 8. **To prevent a security threat means to**
#  **Answer:** Reduce risk
#
# 9. **Types of cryptography include**
#  **Answer:** Symmetric Key Cryptography
